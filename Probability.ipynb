# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravind-Reddy7/ML-Course/blob/main/Probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "/content/car_data_250.csv"
df = pd.read_csv(file_path)
df
# Out:
#      Car ID   Brand        Model  Year     Price  Mileage Fuel Type  \
# 0         1   Tesla  Convertible  2015  63061.53    26.60    Diesel
# 1         2    Audi        Coupe  2018  28953.41    38.51  Electric
# 2         3    Audi          SUV  2013  58224.64    25.45    Diesel
# 3         4  Toyota        Truck  2015  47372.63    33.54    Hybrid
# 4         5  Toyota        Coupe  2014  63283.62    17.41    Hybrid
# ..      ...     ...          ...   ...       ...      ...       ...
# 245     246     BMW  Convertible  2003  65329.67    45.60    Hybrid
# 246     247   Honda          SUV  2008  70418.02    42.71    Hybrid
# 247     248     BMW          SUV  2012  50207.02    30.41  Electric
# 248     249   Honda  Convertible  2013  64287.37    39.45    Hybrid
# 249     250  Toyota        Sedan  2009  34948.79    30.52    Petrol
#
#      Horsepower
# 0           525
# 1           309
# 2           403
# 3           395
# 4           196
# ..          ...
# 245         245
# ...

# %%
# Assuming 'df' is your DataFrame
df.describe(include='all')
# OR
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Car ID      250 non-null    int64
#  1   Brand       250 non-null    object
#  2   Model       250 non-null    object
#  3   Year        250 non-null    int64
#  4   Price       250 non-null    float64
#  5   Mileage     250 non-null    float64
#  6   Fuel Type   250 non-null    object
#  7   Horsepower  250 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 15.8+ KB

# %%
plt.figure(figsize = (10, 5))
sns.histplot(df['Price'], bins = 20, kde = 1, color = 'blue')
plt.title('Distribution of Car Prices', fontsize = 14)
plt.xlabel('Price{$}', fontsize = 12)
plt.ylabel('Frequency', fontsize = 14)
plt.show()

# %%
# Most Common Price Range
most_common_price_range = (df['Price'].min(), df['Price'].max())
print(f"Most Common Price Range: {most_common_price_range}")

# 2. Scatterplot Exploration: Horsepower vs. Mileage
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['Horsepower'], y=df['Mileage'], hue=df['Fuel Type'], palette='viridis', alpha=0.8)
plt.xlabel('Horsepower (HP)', fontsize=12)
plt.ylabel('Mileage (MPG)', fontsize=12)
plt.title('Horsepower vs Mileage', fontsize=14)
sns.regplot(x=df['Horsepower'], y=df['Mileage'], scatter=False, color='red', ci=None)
plt.legend(title="Fuel Type", bbox_to_anchor=(1, 1), loc='upper left')
plt.show()

# Correlation between Horsepower and Mileage
correlation = df[['Horsepower', 'Mileage']].corr().iloc[0,1]
print(f"Correlation between Horsepower and Mileage: {correlation}")
# Out:
# Most Common Price Range: (15517.69, 79757.05)
# Correlation between Horsepower and Mileage: -0.05233363952829577
